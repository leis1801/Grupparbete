# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

x = [2010,2011,2012,2013,2014,2015,2016,2017,2018]
y = [ 11.25,12.39,11.09,11.31,12.33,11.63,12.15,11.29,12.93]
z = [4.2,6.0,3.9,5.0,5.6,5.4,5.6,3.9,5.0]
k = [11.3,12.0,11.8,11.7,13.3,12.2,12.8,12.0,13.3]
v = [10.1,11.2,10.3,10.3,11.8,10.4,11.2,10.7,12.3]
l = [11.9,12.6,12.2,11.9,13.5,12.1,13.0,12.5,14.0]
g = [11.7,12.8,11.9,11.9,13.8,12.4,12.9,12.4,14.4]
t = [10.5,11.2,10.8,10.9,12.0,11.2,11.9,10.9,12.5]
s = [10.8,11.8,11.1,10.9,12.8,11.2,12.0,11.4,12.2]
n = [10.8,12.0,11.1,9.3,12.3,11.5,11.9,11.3,13.4]
d = [9.5,10.9,9.9,9.7,11.3,10.2,10.9,10.2,11.4]
e = [9.2,10.7,9.3,9.7,10.7,9.6,10.2,9.4,10.7]
r = [7.2,8.9,7.0,7.7,8.9,7.6,7.8,6.9,8.1]
u = [8.0,9.1,7.8,8.3,9.1,8.5,8.6,7.6,8.7]
a = [7.5,8.8,7.3,7.7,8.8,8.4,8.2,6.8,8.0]

plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,k)
plt.plot(x,v)
plt.plot(x,l)
plt.plot(x,g)
plt.plot(x,t)
plt.plot(x,s)
plt.plot(x,n)
plt.plot(x,d)
plt.plot(x,e)
plt.plot(x,r)
plt.plot(x,u)
plt.plot(x,a)
plt.title("Snitt temperatur säsong år 2010-2018")
plt.xlabel("Year")
plt.ylabel("Temp C")

plt.legend(["Stockholm", 
            "Kiruna", 
            "Karlskrona", 
            "Vaxsjö", 
            "Lund",
            "Göteborg",
            "Gotland",
            "Strömstad",
            "Norrköping",
            "Karlstad",
            "Borlänge",
            "Östersund",
            "Umeå",
            "Luleå"],fontsize = 'small', loc = 'center left', bbox_to_anchor=(1, 0.5),
          )

plt.show()
